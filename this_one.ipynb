# %% [markdown]
# <a href="https://colab.research.google.com/github/Nathanp44/Spotify-dataset-/blob/main/this_one.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5d797cf1-7f29-4a70-8c0b-efb90c840a2b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5d797cf1-7f29-4a70-8c0b-efb90c840a2b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os


os.makedirs("/root/.kaggle", exist_ok=True)
# !mv kaggle.json /root/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d nelgiriyewithana/top-spotify-songs-2023
# Out:
# Dataset URL: https://www.kaggle.com/datasets/nelgiriyewithana/top-spotify-songs-2023
# License(s): other
# ...
#   0% 0.00/47.1k [00:00<?, ?B/s]
# 100% 47.1k/47.1k [00:00<00:00, 190MB/s]

# %%
import zipfile

with zipfile.ZipFile("top-spotify-songs-2023.zip", 'r') as zip_ref:
    zip_ref.extractall("spotify_2023")

# %%
import os
os.listdir("spotify_2023")
# Out:
# ['spotify-2023.csv']

# %%
import os


print("Main directory contents:", os.listdir())


if "spotify_2023" in os.listdir():
    print("spotify_2023 folder contents:", os.listdir("spotify_2023"))
else:
    print("spotify_2023 folder not found.")
# Out:
# Main directory contents: ['.config', 'top-spotify-songs-2023.zip', 'spotify_2023', 'sample_data']
# spotify_2023 folder contents: ['spotify-2023.csv']

# %%
file_path = "spotify_2023/top-spotify-songs-2023.csv"
print("File exists:", os.path.isfile(file_path))
# Out:
# File exists: False

# %%
import os


print("Current directory:", os.getcwd())


print("Main directory contents:", os.listdir())


if "spotify_2023" in os.listdir():
    print("spotify_2023 contents:", os.listdir("spotify_2023"))
else:
    print("spotify_2023 folder not found.")
# Out:
# Current directory: /content
# Main directory contents: ['.config', 'top-spotify-songs-2023.zip', 'spotify_2023', 'sample_data']
# spotify_2023 contents: ['spotify-2023.csv']

# %%
import pandas as pd

spotify_df = pd.read_csv("spotify_2023/spotify-2023.csv", encoding='latin1')
spotify_df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
spotify_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(spotify_df.columns.tolist())
# Out:
# ['track_name', 'artist(s)_name', 'artist_count', 'released_year', 'released_month', 'released_day', 'in_spotify_playlists', 'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts', 'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm', 'key', 'mode', 'danceability_%', 'valence_%', 'energy_%', 'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%']

# %%
print(spotify_df.dtypes)
# Out:
# track_name              object
# artist(s)_name          object
# artist_count             int64
# released_year            int64
# released_month           int64
# released_day             int64
# in_spotify_playlists     int64
# in_spotify_charts        int64
# streams                 object
# in_apple_playlists       int64
# in_apple_charts          int64
# in_deezer_playlists     object
# in_deezer_charts         int64
# in_shazam_charts        object
# bpm                      int64
# key                     object
# mode                    object
# danceability_%           int64
# valence_%                int64
# energy_%                 int64
# acousticness_%           int64
# instrumentalness_%       int64
# liveness_%               int64
# speechiness_%            int64
# dtype: object

# %%
print(spotify_df.columns.tolist())
# Out:
# ['track_name', 'artist(s)_name', 'artist_count', 'released_year', 'released_month', 'released_day', 'in_spotify_playlists', 'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts', 'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm', 'key', 'mode', 'danceability_%', 'valence_%', 'energy_%', 'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%']

# %%
import matplotlib.pyplot as plt
import seaborn as sns


top_20 = spotify_df.sort_values('streams', ascending=False).head(20)

plt.figure(figsize=(12,6))
sns.barplot(x='streams', y='track_name', data=top_20, palette='viridis')

plt.title('Top 20 Spotify Songs by Streams (2023)')
plt.xlabel('Streams')
plt.ylabel('Track Name')

plt.show()
# Out:
# /tmp/ipython-input-15-1904445685.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='streams', y='track_name', data=top_20, palette='viridis')

# %%
import matplotlib.pyplot as plt
import seaborn as sns


top_20 = spotify_df.sort_values('streams', ascending=False).head(20)

plt.figure(figsize=(10,6))
sns.scatterplot(data=top_20, x='bpm', y='streams', hue='track_name', palette='tab20', s=100)

plt.title('Streams vs BPM for Top 20 Spotify Songs (2023)')
plt.xlabel('BPM (Beats Per Minute)')
plt.ylabel('Streams')
plt.legend(title='Track Name', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# possible questions
#
# Are songs that appear in more Spotify playlists also more likely to chart on Apple, Deezer, and Shazam? whats the strength of these cross-platform correlations?
#
# Do multi artist  tracks perform better than soloartist songs, and what musical or metadata characteristics differ between them?
#
# How do audio features (energy, danceability, valence, acousticness, speechiness, instrumentalness, liveness) collectively predict streaming success?

# %%
spotify_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
features = ['energy_%', 'danceability_%', 'valence_%', 'acousticness_%',
            'speechiness_%', 'instrumentalness_%', 'liveness_%', ]

subset = spotify_df[features]

# %%
print(spotify_df.columns.tolist())
# Out:
# ['track_name', 'artist(s)_name', 'artist_count', 'released_year', 'released_month', 'released_day', 'in_spotify_playlists', 'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts', 'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm', 'key', 'mode', 'danceability_%', 'valence_%', 'energy_%', 'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select features
features = ['energy_%', 'danceability_%', 'valence_%', 'acousticness_%',
            'speechiness_%', 'instrumentalness_%', 'liveness_%', 'in_spotify_playlists']

# Subset the DataFrame
subset = spotify_df[features]

# Compute correlation matrix
corr_matrix = subset.corr()

# Plot the heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(corr_matrix, annot=True, cmap='YlGnBu', fmt='.2f', linewidths=0.5)
plt.title("Correlation Between Audio Features and Spotify Playlist Appearance")
plt.show()

# %%
playlist_corr = subset.corr()['in_spotify_playlists'].drop('in_spotify_playlists')


plt.figure(figsize=(10, 5))
sns.barplot(x=playlist_corr.index, y=playlist_corr.values, palette='viridis')
plt.title("Correlation of Audio Features with Spotify Playlist Count")
plt.ylabel("Correlation with 'in_spotify_playlists'")
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipython-input-21-290529428.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=playlist_corr.index, y=playlist_corr.values, palette='viridis')

# %%
print(spotify_df.isnull().sum())
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %%
duplicates = spotify_df.duplicated().sum()
print(f"Duplicate rows: {duplicates}")
# Out:
# Duplicate rows: 0

# %%
# View data types
print(spotify_df.dtypes)
# Out:
# track_name              object
# artist(s)_name          object
# artist_count             int64
# released_year            int64
# released_month           int64
# released_day             int64
# in_spotify_playlists     int64
# in_spotify_charts        int64
# streams                 object
# in_apple_playlists       int64
# in_apple_charts          int64
# in_deezer_playlists     object
# in_deezer_charts         int64
# in_shazam_charts        object
# bpm                      int64
# key                     object
# mode                    object
# danceability_%           int64
# valence_%                int64
# energy_%                 int64
# acousticness_%           int64
# instrumentalness_%       int64
# liveness_%               int64
# speechiness_%            int64
# dtype: object

# %%
print(spotify_df.describe())
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Boxplot of key features
sns.boxplot(data=spotify_df[['streams' , 'bpm']])
plt.title("Boxplot of Numerical Features")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


features = ['energy_%', 'danceability_%', 'valence_%', 'acousticness_%',
            'speechiness_%', 'instrumentalness_%', 'liveness_%', 'in_spotify_playlists']


subset = spotify_df[features]


corr_matrix = subset.corr()


playlist_corr = corr_matrix['in_spotify_playlists'].drop('in_spotify_playlists')


blues = sns.color_palette("Blues", n_colors=len(playlist_corr))


plt.figure(figsize=(10, 6))
sns.barplot(x=playlist_corr.index, y=playlist_corr.values, palette=blues)
plt.axhline(0, color='gray', linestyle='--')
plt.ylabel('Correlation with Playlist Inclusion')
plt.title('Correlation of Audio Features with Spotify Playlist Inclusion')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-27-4129484927.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=playlist_corr.index, y=playlist_corr.values, palette=blues)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Columns we're analyzing
features = ['in_spotify_playlists', 'in_apple_playlists', 'in_deezer_playlists', 'in_shazam_charts']

# Clean and convert string numbers with commas to actual integers
for col in features:
    spotify_df[col] = spotify_df[col].astype(str).str.replace(',', '').astype(float)

# Create a subset DataFrame
subset = spotify_df[features]

# Compute the correlation matrix
corr_matrix = subset.corr()

# Get correlations between Spotify playlist inclusion and the other platforms
playlist_corr = corr_matrix['in_spotify_playlists'].drop('in_spotify_playlists')

# Define color palette
blues = sns.color_palette("Blues", n_colors=len(playlist_corr))

# Plot the bar graph
plt.figure(figsize=(8, 6))
sns.barplot(x=playlist_corr.index, y=playlist_corr.values, palette=blues)
plt.axhline(0, color='gray', linestyle='--')
plt.ylabel('Pearson Correlation Coefficient')
plt.title('Correlation Between Spotify Playlist Count and Other Platforms')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-28-2009259296.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=playlist_corr.index, y=playlist_corr.values, palette=blues)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#
features = ['in_spotify_playlists', 'in_apple_playlists', 'in_deezer_playlists', 'in_shazam_charts']

for col in features:
    spotify_df[col] = spotify_df[col].astype(str).str.replace(',', '').astype(float)


plt.figure(figsize=(18, 5))

plt.subplot(1, 3, 1)
sns.regplot(
    data=spotify_df,
    x='in_spotify_playlists',
    y='in_apple_playlists',
    scatter_kws={'alpha': 0.6},
    line_kws={'color': 'red'}
)
plt.title('Spotify vs Apple Playlist Inclusion')
plt.xlabel('Spotify Playlists')
plt.ylabel('Apple Playlists')


plt.subplot(1, 3, 2)
sns.regplot(
    data=spotify_df,
    x='in_spotify_playlists',
    y='in_deezer_playlists',
    scatter_kws={'alpha': 0.6},
    line_kws={'color': 'green'}
)
plt.title('Spotify vs Deezer Playlist Inclusion')
plt.xlabel('Spotify Playlists')
plt.ylabel('Deezer Playlists')

plt.subplot(1, 3, 3)
sns.regplot(
    data=spotify_df,
    x='in_spotify_playlists',
    y='in_shazam_charts',
    scatter_kws={'alpha': 0.6},
    line_kws={'color': 'blue'}
)
plt.title('Spotify vs Shazam Chart Appearances')
plt.xlabel('Spotify Playlists')
plt.ylabel('Shazam Charts')

plt.tight_layout()
plt.show()

# %% [markdown]
# Can we predict whether a song belongs to the "Pop" genre based on its audio features using a classification model?

# %%
print(spotify_df.shape)
print(spotify_df.columns)
spotify_df.head()
# Out:
# (953, 24)
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
# ...

# %%
 spotify_df['is_pop'] = spotify_df['genre'].str.lower().str.contains('pop').astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'genre'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-32-1879140848.py in <cell line: 0>()
# ...

# %%
print(spotify_df.columns)
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %%
print(spotify_df['in_spotify_charts'].unique())
# Out:
# [147  48 113 100  50  91  43  83  44  40  55 115  98 130  77 104  68  26
#   38 110  87  19 101  78  34  88  56  49  31  53  42  28  25  80  64  76
#   59  79  47  66  39  69  45  41  29  15  23  36  24  35  63  61  62  20
#   30   9  17  12  46  52  58  27  21  32   6  18  22  11  33  16   8  13
#    7  14  37  10   4   0   5   3   2   1]

# %%
# Step 1: Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
spotify_df['is_charted'] = (spotify_df['in_spotify_charts'] > 0).astype(int)

# %%
features = ['danceability_%', 'energy_%', 'acousticness_%', 'instrumentalness_%',
            'liveness_%', 'valence_%', 'speechiness_%', 'bpm']

X = spotify_df[features]
y = spotify_df['is_charted']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %%
X = spotify_df[features]
y = spotify_df['is_charted']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


importance = model.coef_[0]
features = ['danceability_', 'energy_', 'acousticness_', 'instrumentalness_',
            'liveness_', 'valence_', 'speechiness_', 'bpm']

feature_importance = pd.Series(importance, index=features).sort_values()


plt.figure(figsize=(10, 6))
sns.barplot(x=feature_importance.values, y=feature_importance.index, palette='viridis')
plt.title("🔊 Audio Feature Importance for Predicting Spotify Chart Appearance")
plt.xlabel("Logistic Regression Coefficient")
plt.ylabel("Audio Feature")
plt.grid(True, axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-46-2677585531.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=feature_importance.values, y=feature_importance.index, palette='viridis')
# /tmp/ipython-input-46-2677585531.py:20: UserWarning: Glyph 128266 (\N{SPEAKER WITH THREE SOUND WAVES}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128266 (\N{SPEAKER WITH THREE SOUND WAVES}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
